# %% [markdown]
# ## Coparision of first algorithms

# %% [markdown]
# ### Imports

# %%
import torch
from torch import optim

from comparision import Comparision, OptimizerSchema
from problem import Sphere
from utils import plot_comparision

# %% [markdown]
# ### Test comparision, plotting etc.

# %%
sphere100 = Sphere(dim=5)
dummy_param = torch.zeros(sphere100.dim, requires_grad=True)

optim_schemas = [
    OptimizerSchema(optimizer_class=optim.SGD, params={"lr": 0.1}),
    OptimizerSchema(optimizer_class=optim.Adam, params={"lr": 0.1}),
    OptimizerSchema(optimizer_class=optim.AdamW, params={"lr": 0.1}),
    OptimizerSchema(optimizer_class=optim.RMSprop, params={"lr": 0.1}),
]

comp1 = Comparision(
    sphere100, optim_schemas, epochs=100, repetitions=3, seed=42, log_freq=50
)

comp1.run()
# Out:
# [e311180d-ef74-420b-b610-28a335a81673] Running SGD
# [SGD] Repetition 0 epoch 0: 55.504227
# [SGD] Repetition 0 epoch 50: 0.000000
# Done repetition 0 in 0.79s
# [SGD] Repetition 1 epoch 0: 48.449417
# [SGD] Repetition 1 epoch 50: 0.000000
# Done repetition 1 in 0.01s
# [SGD] Repetition 2 epoch 0: 39.680397
# [SGD] Repetition 2 epoch 50: 0.000000
# Done repetition 2 in 0.01s
# [e311180d-ef74-420b-b610-28a335a81673] Running Adam
# [Adam] Repetition 0 epoch 0: 55.504227
# [Adam] Repetition 0 epoch 50: 0.491026
# Done repetition 0 in 0.02s
# [Adam] Repetition 1 epoch 0: 48.449417
# [Adam] Repetition 1 epoch 50: 0.300912
# Done repetition 1 in 0.02s
# [Adam] Repetition 2 epoch 0: 39.680397
# [Adam] Repetition 2 epoch 50: 0.232797
# Done repetition 2 in 0.02s
# [e311180d-ef74-420b-b610-28a335a81673] Running AdamW
# [AdamW] Repetition 0 epoch 0: 55.504227
# [AdamW] Repetition 0 epoch 50: 0.372261
# Done repetition 0 in 0.02s
# [AdamW] Repetition 1 epoch 0: 48.449417
# [AdamW] Repetition 1 epoch 50: 0.241741
# Done repetition 1 in 0.02s
# [AdamW] Repetition 2 epoch 0: 39.680397
# [AdamW] Repetition 2 epoch 50: 0.178561
# Done repetition 2 in 0.02s
# [e311180d-ef74-420b-b610-28a335a81673] Running RMSprop
# [RMSprop] Repetition 0 epoch 0: 55.504227
# [RMSprop] Repetition 0 epoch 50: 0.000005
# Done repetition 0 in 0.02s
# [RMSprop] Repetition 1 epoch 0: 48.449417
# [RMSprop] Repetition 1 epoch 50: 0.000002
# Done repetition 1 in 0.02s
# [RMSprop] Repetition 2 epoch 0: 39.680397
# [RMSprop] Repetition 2 epoch 50: 0.000001
# Done repetition 2 in 0.02s
# Results saved to experiment_result/Sphere_2025-11-13.json

# %%
plot_comparision("experiment_result/Sphere_2025-11-13.json")
